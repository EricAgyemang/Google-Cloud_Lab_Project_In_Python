# %% [markdown]
# ####Step 1: A quick test to veify if Python is working here:

# %%
print("Hello, world")
# Out:
# Hello, world

# %% [markdown]
# ####Step 2: Mount "IT166" folder from your Google drive to Colab. You can use the similar code to mount any folder/subfolder accordingly.

# %%
from google.colab import drive
import os
drive.mount('/content/drive')
os.chdir("/content/drive/My Drive/IT166/")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ####Step 3: Read a CSV file from the folder

# %%
from pandas import read_csv
data = read_csv('username.csv')
data
# Out:
#   Username   ID Grade
# 0    Alice  111     A
# 1      Bob  222     A
# 2    Cindy  333     A
# 3     Dave  444     A
# 4    Ellen  555     A
